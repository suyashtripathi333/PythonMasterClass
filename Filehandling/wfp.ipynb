# %% [markdown]
# Working with file paths

# %%
#here making new directory named package

import os 

new_directory="package"
os.mkdir(new_directory)

# %%
#listing files and directories
files=os.listdir(".")#. is for current working location
print(files)
# Out:
# ['destin.txt', 'file.bin', 'filehandling.ipynb', 'new.txt', 'package', 'wfp.ipynb']

# %%
#Joining Paths
dir_name="folder"
file_name="file.txt"
full_path = os.path.join(os.getcwd(),dir_name,file_name)
print(full_path)
# Out:
# c:\Users\tripa\OneDrive\Desktop\LearnPy\complete_python folder\Filehandling\folder\file.txt

# %%
path = "example.txt"
if os.path.exists(path):
    print(f"The path {path} exists")
else:
    print(f"The path {path} do not exists")
# Out:
# The path example.txt do not exists

# %%
#check psth is afile or directory
path = "new.txt"

if os.path.isfile(path):
    print(f"The path {path} is a file")
elif os.path.isdir(path):
    print(f"The path {path} is a directory")
else:
    print(f"The path {path} is neither a file nor a directory")
# Out:
# The path new.txt is a file

# %%
#getting the absolute path
relative_path = "example.txt"
absolute_path = os.path.abspath(relative_path)
print(absolute_path)
# Out:
# c:\Users\tripa\OneDrive\Desktop\LearnPy\complete_python folder\Filehandling\example.txt
